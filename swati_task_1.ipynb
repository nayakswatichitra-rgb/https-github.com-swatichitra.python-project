# %% [markdown]
# <a href="https://colab.research.google.com/github/nayakswatichitra-rgb/https-github.com-swatichitra.python-project/blob/main/swati_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_name = input("enter the students name:")
print("uppercase Name:",student_name.upper())
# Out:
# enter the students name:swatichitra
# uppercase Name: SWATICHITRA

# %%
city_name = input("enter a city name:")
print("original name:",city_name)
print("uppercase:",city_name.upper())
print("lowercase:",city_name.lower())
print("Title Case:",city_name.title())
# Out:
# enter a city name:bhubaneswar
# original name: bhubaneswar
# uppercase: BHUBANESWAR
# lowercase: bhubaneswar
# Title Case: Bhubaneswar

# %%
text =input("enter a string:")
print("Total Lenth:",len(text))
# Out:
# enter a string:1
# Total Lenth: 1

# %%
text = input("Enter a string:")

if len(text) > 0:

  print("First character:",text[0])
  print("Last character:",text[-1] )
else:
  print("string is empty.")
# Out:
# Enter a string:swatichitra
# First character: s
# Last character: a

# %%
text =input("Enter a string:")
count_a = text.lower().count('a')
print("Number of 'a' characters:",count_a)
# Out:
# Enter a string:swatichitra
# Number of 'a' characters: 2

# %%
sentence = input("enter a sentence:")
updated_sentence = sentence.replace("python","AI")
print("updated sentence:",updated_sentence)
# Out:
# enter a sentence:python is a language
# updated sentence: AI is a language

# %%
email = input("Enter email address: ")

if email.endswith("@gmail.com"):
    print("Valid Gmail Address")
else:
    print("Not a Gmail Address")
# Out:
# Enter email address: nayakswatichitra@gmail.ccom
# Not a Gmail Address

# %%
text = input("Enter input: ")

if text.isdigit():
    print("Contains only digits")
else:
    print("Does not contain only digits")
# Out:
# Enter input: 567
# Contains only digits

# %%
text = input("Enter input: ")

if text.isalpha():
    print("Contains only alphabets")
else:
    print("Does not contain only alphabets")
# Out:
# Enter input: abcde
# Contains only alphabets

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible to Vote")
# Out:
# Enter age: 18
# Eligible to Vote

# %%
num = float(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: 345
# Positive

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if num1 > num2:
    print("Greater Number:", num1)
else:
    print("Greater Number:", num2)
# Out:
# Enter first number: 234
# Enter second number: 456
# Greater Number: 456.0

# %%
marks = int(input("Enter marks: "))

if 90 <= marks <= 100:
    print("Grade A")
elif 75 <= marks <= 89:
    print("Grade B")
elif 50 <= marks <= 74:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 567
# Fail

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 24
# Even

# %%
password = input("Enter password: ")

if len(password) >= 8:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter password: swati@123
# Strong Password

# %%
year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2004
# Leap Year

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest Number:", a)
elif b >= a and b >= c:
    print("Largest Number:", b)
else:
    print("Largest Number:", c)
# Out:
# Enter first number: 342
# Enter second number: 345
# Enter third number: 567
# Largest Number: 567.0

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: swati
# Enter password: swati@123
# Invalid Credentials

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result:", num1 + num2)
elif operator == "-":
    print("Result:", num1 - num2)
elif operator == "*":
    print("Result:", num1 * num2)
elif operator == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Division by zero is not allowed")
else:
    print("Invalid Operator")
# Out:
# Enter first number: 34
# Enter second number: 56
# Enter operator (+, -, *, /): +
# Result: 90.0
